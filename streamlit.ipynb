# %%
# %pip install -q streamlit langchain PyPDF2 faiss-cpu tiktoken huggingface-hub
# %pip install langchain-huggingface
# %pip install python-docx
# %pip install -U langchain-community
# %pip install openpyxl
# %pip install langchain-openai
# %pip install python-dotenv
# %pip install openai
# %pip install tokenizers==0.19.0
# %pip install transformers --upgrade
# %pip install pillow
# %pip install pytesseract
# Out:
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.1.1 -> 25.2
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.1.1 -> 25.2
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.1.1 -> 25.2
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ...
#    ---------------------------------------- 0.0/2.5 MB ? eta -:--:--
#    -------- ------------------------------- 0.5/2.5 MB 3.4 MB/s eta 0:00:01
#    ---------------- ----------------------- 1.0/2.5 MB 3.4 MB/s eta 0:00:01
#    ----------------------------- ---------- 1.8/2.5 MB 3.4 MB/s eta 0:00:01
#    ---------------------------------------- 2.5/2.5 MB 3.5 MB/s eta 0:00:00
# ...

# %%
import os
from dotenv import load_dotenv

# Charger les variables du fichier .env
load_dotenv()

# Récupérer la clé
api_key = os.getenv("openai")

print(api_key)  # Vérifie que ça fonctionne
# Out:
# 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

# %%
# %%writefile Streamlit.py
import streamlit as st
from PyPDF2 import PdfReader
#from transformers import pipeline, AutoTokenizer, AutoModelForCausalLM
from langchain.text_splitter import CharacterTextSplitter
import os
from dotenv import load_dotenv
from langchain_community.embeddings import OpenAIEmbeddings, HuggingFaceInstructEmbeddings
from langchain_community.vectorstores import FAISS
from langchain_community.chat_models import ChatOpenAI
from langchain_community.llms import HuggingFaceHub, HuggingFacePipeline

from langchain.memory import ConversationBufferMemory
from langchain.chains import ConversationalRetrievalChain
from langchain.prompts import PromptTemplate
from langchain_openai import ChatOpenAI
from langchain_huggingface import HuggingFaceEmbeddings
from flask import Flask, request, jsonify
from threading import Thread

# Autres librairies
from htmltemplate import css, bot_template, user_template
import pandas as pd
import docx
import io
from openpyxl import load_workbook
import torch
from PIL import Image
import pytesseract


load_dotenv()

# Récupérer la clé
api_key = os.getenv("openai")

# Créer une application Flask
app = Flask(__name__)


def extract_text_from_files(uploaded_files):
    all_text = ""

    for uploaded_file in uploaded_files:
        file_name = uploaded_file.name.lower()

        # PDF
        if file_name.endswith(".pdf"):
            try:
                pdf_reader = PdfReader(uploaded_file)
                for page in pdf_reader.pages:
                    text = page.extract_text()
                    if text:
                        all_text += text + "\n"
            except:
                st.warning(f" Failed to read PDF: {uploaded_file.name}")

        # TXT
        elif file_name.endswith(".txt"):
            stringio = io.StringIO(uploaded_file.getvalue().decode("utf-8"))
            all_text += stringio.read() + "\n"

        # CSV
        elif file_name.endswith(".csv"):
            try:
                df = pd.read_csv(uploaded_file)
                all_text += df.to_string(index=False) + "\n"
            except:
                st.warning(f" Failed to read CSV: {uploaded_file.name}")

        # DOCX
        elif file_name.endswith(".docx"):
            try:
                doc = docx.Document(uploaded_file)
                for para in doc.paragraphs:
                    all_text += para.text + "\n"
            except:
                st.warning(f" Failed to read DOCX: {uploaded_file.name}")

        # XLSX
        elif file_name.endswith(".xlsx"):
            try:
                wb = load_workbook(uploaded_file, data_only=True)
                for sheet in wb.sheetnames:
                    ws = wb[sheet]
                    for row in ws.iter_rows(values_only=True):
                        row_text = " | ".join([str(cell) if cell is not None else "" for cell in row])
                        all_text += row_text + "\n"
            except:
                st.warning(f" Failed to read XLSX: {uploaded_file.name}")

        # PNG, JPG (image OCR)
        elif file_name.endswith((".png", ".jpg", ".jpeg")):
            try:
                image = Image.open(uploaded_file)
                text = pytesseract.image_to_string(image, lang='eng')  # ou 'fra' si c’est en français
                all_text += text + "\n"
            except Exception as e:
                st.warning(f" Failed to extract text from image {uploaded_file.name}: {e}")

        else:
            st.warning(f"Unsupported file type: {uploaded_file.name}")

    return all_text






def get_text_chuncks(text):
  text_splitter=CharacterTextSplitter(separator="\n",chunk_size=1000,chunk_overlap=300,length_function=len)
  chunks=text_splitter.split_text(text)
  return chunks



def get_vectorstore(text_chunks):
    embeddings = OpenAIEmbeddings(openai_api_key=api_key)

    vectorstore = FAISS.from_texts(texts=text_chunks, embedding=embeddings)
    return vectorstore


def get_conversation_chain(vectorstore):
    #tokenizer = AutoTokenizer.from_pretrained("mistralai/Mistral-7B-Instruct-v0.1")
    #model = AutoModelForCausalLM.from_pretrained("mistralai/Mistral-7B-Instruct-v0.1",device_map="cuda",torch_dtype=torch.float16,)
    #load_in_4bit=True,)
    #tokenizer = AutoTokenizer.from_pretrained("rouabenyahia/FineTuningModel")
    #model = AutoModelForCausalLM.from_pretrained("rouabenyahia/FineTuningModel")

    #pipe = pipeline(
        #"text-generation",
        #model=model,
        #tokenizer=tokenizer,
        #max_new_tokens=200,
        #temperature=0.1,
        #do_sample=True,

    #)
    #llm = HuggingFacePipeline(pipeline=pipe)
    llm = ChatOpenAI(
        openai_api_key=api_key,
        model="gpt-4o-mini",
        temperature=0,
        max_tokens=500
    )

    memory = ConversationBufferMemory(
        memory_key='chat_history', return_messages=True
    )

    prompt_template = """
    Instructions :
      1. Avant de répondre, analyse la question pour déterminer si elle implique une action sur les rendez-vous ou un fichier :
        - Ajouter un rendez-vous
        -Donne moi la liste des rendez-vous
        - Modifier un rendez-vous
        - Supprimer un rendez-vous
        - Uploader un fichier
        -Envoyer un email de rappel
      2. Si une action est détectée, réponds uniquement avec :
        "Action détectée : [type d'action]"
      3. Sinon, réponds normalement à la question en utilisant uniquement le contexte fourni.
      4. Ne devine jamais la réponse si elle n’est pas dans le contexte.

      Contexte:
      {context}

      Question:
      {question}

      Réponse:
"""


    prompt = PromptTemplate.from_template(prompt_template)

    conversation_chain = ConversationalRetrievalChain.from_llm(
        llm=llm,
        retriever = vectorstore.as_retriever(search_kwargs={"k": 5}),
        #retriever=vectorstore.as_retriever(),
        memory=memory,
        combine_docs_chain_kwargs={"prompt": prompt}
    )
    return conversation_chain




def handle_userinput(user_question):
    retriever = st.session_state.conversation.retriever
    docs = retriever.get_relevant_documents(user_question)

    if len(docs) == 0:
        st.warning(" Aucun passage du document n’a été trouvé pour cette question. Essayez de reformuler.")
        return

    # Obtenir la réponse du modèle
    response = st.session_state.conversation({'question': user_question})
    st.session_state.chat_history = response['chat_history']

    # Vérifier si une action est détectée dans la réponse
    last_message = response['chat_history'][-1].content
    if "Action détectée" in last_message:
        #  action_detected = last_message.split("Action détectée :")[-1].strip()
        st.warning("Une action a été détectée. Les données seront envoyées.")
        send_action_data(user_question, st.session_state.uploaded_files, last_message)
        return

    # Afficher la conversation normale si aucune action n'est détectée
    for i, message in enumerate(st.session_state.chat_history):
        content = message.content
        if i % 2 == 1:
            if "Réponse:" in content:
                content = content.split("Réponse:")[-1].strip()
            st.write(bot_template.replace("{{MSG}}", content), unsafe_allow_html=True)
        else:
            st.write(user_template.replace("{{MSG}}", content), unsafe_allow_html=True)

import requests

webhook_url = "https://rouabenyahia.app.n8n.cloud/webhook-test/55155e29-bc8d-47c7-be4c-7af3a3e23ffe"


def send_action_data(user_question, uploaded_files, action_message):
    """
    Envoie les données textuelles et les fichiers en binaire au webhook n8n.
    uploaded_files : liste de fichiers Streamlit (UploadedFile)
    """

    # Préparer les données textuelles
    data = {
        "action_detected": action_message,
        "user_question": user_question,
    }

    # Préparer les fichiers (multipart/form-data)
    files = []
    for uploaded_file in uploaded_files:
        file_name = uploaded_file.name
        file_type = uploaded_file.type or "application/octet-stream"

        # ⚡ Utiliser .getvalue() (retourne les bytes du fichier)
        files.append(("files", (file_name, uploaded_file.getvalue(), file_type)))

    # Envoyer au webhook
    try:
        response = requests.post(webhook_url, data=data, files=files)
        if response.status_code == 200:
            st.success(" Les fichiers ont été envoyés avec succès à n8n.")
        else:
            st.error(f" Erreur {response.status_code} : {response.text}")
    except Exception as e:
        st.error(f" Exception lors de l'envoi : {e}")




# Route pour recevoir les données JSON avec vérification du token
@app.route('/webhook', methods=['POST'])
def webhook():
    data = request.json  # Récupérer les données JSON envoyées par n8n
    st.session_state.received_data = data  # Stocker les données dans Streamlit
    return jsonify({"status": "success", "message": "Données reçues avec succès"}), 200
# Fonction pour démarrer le serveur Flask dans un thread séparé
def start_flask():
    app.run(port=8000, debug=False, use_reloader=False)        








st.set_page_config(
    page_title="Chat with your data",
    page_icon=":books:",
)

st.write(css,unsafe_allow_html=True)

if "conversation" not in st.session_state:
  st.session_state.conversation=None


if "chat_history" not in st.session_state:
  st.session_state.chat_history=None

st.header("Chat with your data :books:")

#user_question=st.text_input("Ask a question about your documents")
#if user_question:
  #handle_userinput(user_question)

user_question = st.text_input("Ask a question about your documents")

if user_question and st.session_state.conversation is not None:
    handle_userinput(user_question)
elif user_question:
    st.warning("📄 Veuillez d'abord uploader vos fichiers et cliquer sur 'Process'.")




with st.sidebar:
    st.subheader("Your documents")
    uploaded_files = st.file_uploader(
        "Upload your files (.pdf, .txt, .csv, .docx, .xlsx, .png, .jpg, .jpeg) and click on 'Process'",
        type=["pdf", "txt", "csv", "docx", "xlsx","png","jpg","jpeg"],
        accept_multiple_files=True
    )

    if uploaded_files:
        st.session_state.uploaded_files = uploaded_files

    if st.button("Process"):
        with st.spinner("Processing"):
            raw_text = extract_text_from_files(uploaded_files)
            if not raw_text.strip():
                st.error(" Aucun texte n’a été extrait. Les fichiers sont peut-être vides ou illisibles.")
                st.stop()
            else:
                st.write(f" Nombre de caractères extraits: {len(raw_text)}")

            # 🔹 Créer de nouveaux chunks
            text_chunks = get_text_chuncks(raw_text)

            # 🔹 Créer un nouveau vectorstore frais
            vectorstore = get_vectorstore(text_chunks)

            # 🔹 Créer une nouvelle conversation
            st.session_state.conversation = get_conversation_chain(vectorstore)

        st.success(" Le traitement des fichiers est terminé, vous pouvez poser vos questions maintenant !")


    # Démarrer le serveur Flask dans un thread
    if "flask_thread" not in st.session_state:
        st.session_state.flask_thread = Thread(target=start_flask, daemon=True)
        st.session_state.flask_thread.start()

    # Afficher les données reçues dans Streamlit
    #st.header("Données reçues de n8n")
    #if "received_data" in st.session_state:
        #st.json(st.session_state.received_data)
    #else:
        #st.write("Aucune donnée reçue pour le moment.")



    #get the pdf text
    #get the text chuncks
    #create the vector store with the embeddings
  #juste el api key mtaa hugging face bech nhothaa
# Out:
# Overwriting Streamlit.py
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
